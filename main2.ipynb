# %%
print("Hello from juyter notebook")
# Out:
# Hello from juyter notebook

# %%
a=20
b=30
a+b
# Out:
# 50

# %% [markdown]
# # Linear Regression
# this notebook will explain linear regression

# %%
# Python

# ↓

# Libraries

# ↓

# NumPy
# Pandas
# LangChain
# Transformers
# OpenAI
# FastAPI
# Streamlit

# %%
# Python

# ↓

# pip    prefererd installeer program

# ↓

# PyPI       python; package index



# Libraries

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.3.5

# %%
pip install numpy pandas langchain transformers openai fastapi streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ---------------------------------------- 561.6/561.6 kB 6.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 675.2/675.2 kB 7.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.6 MB 11.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.6 MB 11.8 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.6 MB 11.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 10.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/771.9 kB ? eta -:--:--
#    ---------------------------------------- 771.9/771.9 kB 9.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
# ...
